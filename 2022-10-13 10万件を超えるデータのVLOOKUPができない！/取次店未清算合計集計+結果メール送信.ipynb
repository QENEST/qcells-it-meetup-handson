# %% [markdown]
# # 取次店未清算合計集計（例）
#
# * 自分のGoogle Driveにある　「取次店手数料_2021年10月から2022年10月まで.xlsx」　ファイルの　「Sheet1]　シートを　「df1」　に読み込む
# * 自分のGoogle Driveにある　「取次店マスタ_202210.xlsx」　ファイルの　「Sheet1]　シートを　「df2」　に読み込む
# * 「df1」の　'清算'カラムを　'未清算'にフィルターし、　'取次店番号', '取次店番号（サブ）'でピボット（GroupBy)し、'取次店手数料（円）'の合計を出す
# * ピボットしたindex（'取次店番号', '取次店番号（サブ）'）にVLOOKUPをかけるため、indexをカラムに変換し、変換したものを　「df3」　に入れる
# * 「df3」　に対して　「df2」　の同じカラムを基準にVLOOKUPする（merge）
#   * その結果を　'取次店手数料（円）'　が大きい順に並び替える
#   * 並び替えた結果を　「df4」　に入れる
# * 「df4」　を　「未清算取次店金額一蘭_20211001-20221012.xlsx」　に保存する

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = pd.read_excel('drive/MyDrive/取次店手数料_2021年10月から2022年10月まで.xlsx', sheet_name='Sheet1')

# %%
df2 = pd.read_excel('drive/MyDrive/取次店マスタ_202210.xlsx', sheet_name='Sheet1')

# %%
df1
# Out:
#                年月日    お客様番号  取次店番号  取次店番号（サブ）  取次店手数料（円）   清算
# 0       2021-10-01  17228.0  151.0        5.0   -10000.0   済み
# 1       2021-10-01  11828.0  170.0        5.0        0.0   済み
# 2       2021-10-01  17602.0  103.0        7.0   180000.0   済み
# 3       2021-10-01  10564.0  104.0        5.0   160000.0   済み
# 4       2021-10-01  13421.0  173.0        6.0   270000.0   済み
# ...            ...      ...    ...        ...        ...  ...
# 251152  2022-10-12  18434.0  119.0        1.0   175000.0  未清算
# 251153  2022-10-12  14381.0  174.0        2.0   180000.0   済み
# 251154  2022-10-12  14508.0  132.0        7.0    30000.0   済み
# 251155  2022-10-12  15214.0  112.0        3.0   100000.0   済み
# 251156  2022-10-12  11908.0  153.0        2.0   -10000.0   済み
#
# [251157 rows x 6 columns]

# %%
df1[df1['清算']=='未清算']
# Out:
#                年月日    お客様番号  取次店番号  取次店番号（サブ）  取次店手数料（円）   清算
# 7       2021-10-01  19854.0  137.0        7.0   -45000.0  未清算
# 8       2021-10-01  19754.0  135.0        5.0   -45000.0  未清算
# 10      2021-10-01  12231.0  103.0        4.0   -35000.0  未清算
# 11      2021-10-01  13800.0  157.0        3.0    25000.0  未清算
# 18      2021-10-01  15122.0  110.0        5.0    30000.0  未清算
# ...            ...      ...    ...        ...        ...  ...
# 251115  2022-10-12  14127.0  172.0        1.0   120000.0  未清算
# 251126  2022-10-12  18942.0  142.0        2.0    15000.0  未清算
# 251134  2022-10-12  17055.0  118.0        2.0    20000.0  未清算
# 251139  2022-10-12  19644.0  150.0        3.0   120000.0  未清算
# 251152  2022-10-12  18434.0  119.0        1.0   175000.0  未清算
#
# [25257 rows x 6 columns]

# %%
df1[df1['清算']=='未清算'][['取次店番号','取次店番号（サブ）','取次店手数料（円）']].groupby(['取次店番号', '取次店番号（サブ）']).sum('取次店手数料（円）')
# Out:
#                  取次店手数料（円）
# 取次店番号 取次店番号（サブ）
# 100.0 1.0        1635000.0
#       2.0        2205000.0
#       3.0        1920000.0
#       4.0        2810000.0
#       5.0        1525000.0
# ...                    ...
# 179.0 3.0        2355000.0
#       4.0        2010000.0
#       5.0        3640000.0
#       6.0        3750000.0
#       7.0        2825000.0
#
# [560 rows x 1 columns]

# %%
df1[df1['清算']=='未清算'][['取次店番号','取次店番号（サブ）','取次店手数料（円）']].groupby(['取次店番号', '取次店番号（サブ）']).sum('取次店手数料（円）').reset_index()
# Out:
#      取次店番号  取次店番号（サブ）  取次店手数料（円）
# 0    100.0        1.0  1635000.0
# 1    100.0        2.0  2205000.0
# 2    100.0        3.0  1920000.0
# 3    100.0        4.0  2810000.0
# 4    100.0        5.0  1525000.0
# ..     ...        ...        ...
# 555  179.0        3.0  2355000.0
# 556  179.0        4.0  2010000.0
# 557  179.0        5.0  3640000.0
# 558  179.0        6.0  3750000.0
# 559  179.0        7.0  2825000.0
#
# [560 rows x 3 columns]

# %%
df3 = df1[df1['清算']=='未清算'][['取次店番号','取次店番号（サブ）','取次店手数料（円）']].groupby(['取次店番号', '取次店番号（サブ）']).sum('取次店手数料（円）').reset_index()

# %%
df2
# Out:
#      取次店番号  取次店番号（サブ）      取次店名        支店名                               住所  \
# 0      151          5  合同会社山口印刷       中央支店       沖縄県府中市浅草橋31丁目4番8号 今戸コーポ909
# 1      170          5  合同会社藤原農林    川崎市川崎支店   石川県川崎市幸区氏家新田37丁目1番16号 アーバン睦637
# 2      103          7  池田鉱業合同会社       台東支店             徳島県香取郡東庄町木立26丁目7番15号
# 3      104          5  株式会社石川印刷       多摩支店    宮崎県文京区千塚18丁目16番19号 コーポ西小来川622
# 4      173          6  合同会社石川印刷  西多摩郡日の出支店  福島県印旛郡本埜村池之端16丁目1番18号 シャルム千塚163
# ..     ...        ...       ...        ...                              ...
# 555    161          1  株式会社加藤食品         本店   群馬県神津島村一ツ橋18丁目7番12号 西浅草シャルム604
# 556    159          2  斎藤電気有限会社  西多摩郡日の出支店          神奈川県東村山市前弥六南町11丁目24番13号
# 557    124          4  井上建設合同会社       多摩支店     愛媛県福生市二つ室24丁目13番14号 ハイツ白金599
# 558    132          6  有限会社村上農林    安房郡鋸南支店      北海道山武市木立22丁目20番2号 隼町シャルム829
# 559    153          6  有限会社伊藤情報       富津支店            島根県印旛郡印旛村南赤田12丁目7番17号
#
#        担当者                       会社メール
# 0     池田 舞  tsubasamatsuda@yoshida.com
# 1    太田 太一      taroaoki@matsumoto.com
# 2     斎藤 晃       momoko83@nishimura.jp
# 3     林 和也         nanamiogawa@goto.jp
# 4    高橋 春香           pnakagawa@sato.jp
# ..     ...                         ...
# 555  小川 太郎     ryosukeshimizu@sato.com
# 556  岡田 真綾          manabu86@fukuda.jp
# 557  松田 陽子    miturumurakami@kimura.jp
# 558  斎藤 知実        qyamazaki@sasaki.com
# 559  松本 裕樹         satomi80@kimura.org
#
# [560 rows x 7 columns]

# %%
df3.merge(df2, how='left')
# Out:
#      取次店番号  取次店番号（サブ）  取次店手数料（円）      取次店名      支店名  \
# 0    100.0        1.0  1635000.0  前田鉱業有限会社       本店
# 1    100.0        2.0  2205000.0  有限会社藤原印刷    八王子支店
# 2    100.0        3.0  1920000.0  有限会社西村保険  山武郡芝山支店
# 3    100.0        4.0  2810000.0  中島ガス株式会社  山武郡芝山支店
# 4    100.0        5.0  1525000.0  近藤印刷株式会社  横浜市都筑支店
# ..     ...        ...        ...       ...      ...
# 555  179.0        3.0  2355000.0  吉田食品株式会社    青ヶ島支店
# 556  179.0        4.0  2010000.0  有限会社小林銀行     浦安支店
# 557  179.0        5.0  3640000.0  清水電気合同会社     清瀬支店
# 558  179.0        6.0  3750000.0  田中銀行合同会社   横浜市中支店
# 559  179.0        7.0  2825000.0  合同会社藤原電気    武蔵野支店
#
#                                              住所     担当者  \
# 0             大分県西多摩郡瑞穂町小入30丁目10番18号 東三島アーバン282   岡田 智也
# 1                            岩手県稲城市松浦町10丁目17番6号   山崎 七夏
# 2              群馬県川崎市多摩区中川崎3丁目17番15号 白金台クレスト071    小林 零
# 3                沖縄県山武郡九十九里町湯宮2丁目9番14号 千塚コート461   清水 桃子
# 4                           京都府狛江市浅草橋24丁目18番19号   坂本 知実
# ..                                          ...     ...
# 555                宮崎県鴨川市羽折町2丁目18番19号 東神田コート031  石井 裕美子
# 556               宮崎県調布市上広谷39丁目25番10号 シャルム鳥越808   藤井 陽一
# 557  宮崎県横浜市戸塚区虎ノ門虎ノ門ヒルズ森タワー31丁目24番11号 南郷屋シティ907   斉藤 里佳
# 558                           岩手県練馬区平河町24丁目6番3号   長谷川 学
# 559                            熊本県大田区外神田8丁目8番7号   阿部 香織
#
#                          会社メール
# 0         yumiko71@nakajima.jp
# 1        naokifujii@shimizu.jp
# 2            bfujiwara@aoki.jp
# 3        ishiikazuya@okada.net
# 4         akiraishii@miura.net
# ..                         ...
# 555     yamadayoichi@ogawa.com
# 556       naoki40@takahashi.jp
# 557  nakagawaminoru@yamada.com
# 558        jyamashita@aoki.net
# 559        kaori47@watanabe.jp
#
# [560 rows x 8 columns]

# %%
df3.merge(df2, how='left').sort_values('取次店手数料（円）', ascending=False)
# Out:
#      取次店番号  取次店番号（サブ）  取次店手数料（円）      取次店名       支店名  \
# 310  144.0        3.0  4115000.0  合同会社斉藤保険      足立支店
# 316  145.0        2.0  3960000.0  岡田電気有限会社      印西支店
# 26   103.0        6.0  3950000.0  合同会社坂本通信   横浜市青葉支店
# 529  175.0        5.0  3905000.0  合同会社加藤運輸      江東支店
# 72   110.0        3.0  3890000.0  有限会社山本銀行  山武郡横芝光支店
# ..     ...        ...        ...       ...       ...
# 335  147.0        7.0   920000.0  合同会社斉藤鉱業   川崎市宮前支店
# 76   110.0        7.0   870000.0  株式会社加藤電気      渋谷支店
# 304  143.0        4.0   855000.0  合同会社石川銀行   長生郡長生支店
# 138  119.0        6.0   835000.0  太田通信合同会社   八丈島八丈支店
# 369  152.0        6.0   600000.0  鈴木食品有限会社      稲城支店
#
#                                         住所      担当者                    会社メール
# 310  鹿児島県横浜市旭区丸の内ＪＰタワー27丁目19番1号 九段南シャルム740    藤田 知実  atsushi84@yamaguchi.com
# 316                       広島県富里市丹勢39丁目4番2号     山本 学      rnakagawa@maeda.net
# 26               三重県港区脚折町19丁目8番4号 京橋コーポ412     田中 零      fishikawa@inoue.org
# 529         徳島県長生郡長生村西浅草11丁目9番17号 日光パーク302    橋本 結衣      tomoyamori@goto.org
# 72                    滋賀県西東京市松浦町31丁目10番19号    岡本 真綾          hmiura@kondo.jp
# ..                                     ...      ...                      ...
# 335                   千葉県横浜市南区東神田8丁目17番12号    木村 太一     maayasakamoto@abe.jp
# 76             千葉県国分寺市芝浦9丁目2番4号 吾妻橋アーバン103   斎藤 聡太郎      kenichi05@sasaki.jp
# 304       福島県西多摩郡奥多摩町浅草橋39丁目2番2号 パレス白金台771    阿部 裕樹     tomoya74@yamazaki.jp
# 138           佐賀県印西市日光9丁目23番16号 パレス皇居外苑515  佐々木 聡太郎    ryamashita@yoshida.jp
# 369         福井県横浜市緑区所野14丁目7番11号 コート外国府間740    三浦 京助    sasakikyosuke@ota.com
#
# [560 rows x 8 columns]

# %%
df4 = df3.merge(df2, how='left').sort_values('取次店手数料（円）', ascending=False)

# %%
filename = '未清算取次店金額一蘭_20211001-20221012.xlsx'

# %%
df4.to_excel(f'drive/MyDrive/{filename}', index=False)

# %%
df4.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>取次店番号</th>\n      <th>取次店番号（サブ）</th>\n      <th>取次店手数料（円）</th>\n      <th>取次店名</th>\n      <th>支店名</th>\n      <th>住所</th>\n      <th>担当者</th>\n      <th>会社メール</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>310</th>\n      <td>144.0</td>\n      <td>3.0</td>\n      <td>4115000.0</td>\n      <td>合同会社斉藤保険</td>\n      <td>足立支店</td>\n      <td>鹿児島県横浜市旭区丸の内ＪＰタワー27丁目19番1号 九段南シャルム740</td>\n      <td>藤田 知実</td>\n      <td>atsushi84@yamaguchi.com</td>\n    </tr>\n    <tr>\n      <th>316</th>\n      <td>145.0</td>\n      <td>2.0</td>\n      <td>3960000.0</td>\n      <td>岡田電気有限会社</td>\n      <td>印西支店</td>\n      <td>広島県富里市丹勢39丁目4番2号</td>\n      <td>山本 学</td>\n      <td>rnakagawa@maeda.net</td>\n    </tr>\n    <tr>\n      <th>26</th>\n      <td>103.0</td>\n      <td>6.0</td>\n      <td>3950000.0</td>\n      <td>合同会社坂本通信</td>\n      <td>横浜市青葉支店</td>\n      <td>三重県港区脚折町19丁目8番4号 京橋コーポ412</td>\n      <td>田中 零</td>\n      <td>fishikawa@inoue.org</td>\n    </tr>\n    <tr>\n      <th>529</th>\n      <td>175.0</td>\n      <td>5.0</td>\n      <td>3905000.0</td>\n      <td>合同会社加藤運輸</td>\n      <td>江東支店</td>\n      <td>徳島県長生郡長生村西浅草11丁目9番17号 日光パーク302</td>\n      <td>橋本 結衣</td>\n      <td>tomoyamori@goto.org</td>\n    </tr>\n    <tr>\n      <th>72</th>\n      <td>110.0</td>\n      <td>3.0</td>\n      <td>3890000.0</td>\n      <td>有限会社山本銀行</td>\n      <td>山武郡横芝光支店</td>\n      <td>滋賀県西東京市松浦町31丁目10番19号</td>\n      <td>岡本 真綾</td>\n      <td>hmiura@kondo.jp</td>\n    </tr>\n    <tr>\n      <th>77</th>\n      <td>111.0</td>\n      <td>1.0</td>\n      <td>3860000.0</td>\n      <td>有限会社加藤保険</td>\n      <td>本店</td>\n      <td>佐賀県台東区虎ノ門10丁目12番2号</td>\n      <td>藤井 千代</td>\n      <td>jota@kobayashi.jp</td>\n    </tr>\n    <tr>\n      <th>558</th>\n      <td>179.0</td>\n      <td>6.0</td>\n      <td>3750000.0</td>\n      <td>田中銀行合同会社</td>\n      <td>横浜市中支店</td>\n      <td>岩手県練馬区平河町24丁目6番3号</td>\n      <td>長谷川 学</td>\n      <td>jyamashita@aoki.net</td>\n    </tr>\n    <tr>\n      <th>168</th>\n      <td>124.0</td>\n      <td>1.0</td>\n      <td>3745000.0</td>\n      <td>太田水産合同会社</td>\n      <td>本店</td>\n      <td>栃木県印旛郡本埜村虎ノ門18丁目6番11号 シャルム隼町481</td>\n      <td>三浦 晃</td>\n      <td>taroito@ito.com</td>\n    </tr>\n    <tr>\n      <th>345</th>\n      <td>149.0</td>\n      <td>3.0</td>\n      <td>3735000.0</td>\n      <td>株式会社村上銀行</td>\n      <td>小笠原支店</td>\n      <td>山梨県山武郡芝山町池之端41丁目5番6号 浅草パレス061</td>\n      <td>松本 七夏</td>\n      <td>jkondo@aoki.jp</td>\n    </tr>\n    <tr>\n      <th>477</th>\n      <td>168.0</td>\n      <td>2.0</td>\n      <td>3705000.0</td>\n      <td>株式会社斉藤農林</td>\n      <td>三宅島三宅支店</td>\n      <td>福岡県香取郡東庄町前弥六39丁目14番5号 パレス三ノ輪263</td>\n      <td>石川 里佳</td>\n      <td>kondokumiko@tanaka.com</td>\n    </tr>\n    <tr>\n      <th>301</th>\n      <td>143.0</td>\n      <td>1.0</td>\n      <td>3675000.0</td>\n      <td>佐藤通信有限会社</td>\n      <td>本店</td>\n      <td>静岡県町田市芝浦19丁目26番1号 鶴ヶ丘パレス328</td>\n      <td>岡本 美加子</td>\n      <td>nakajimashohei@miura.jp</td>\n    </tr>\n    <tr>\n      <th>452</th>\n      <td>164.0</td>\n      <td>5.0</td>\n      <td>3665000.0</td>\n      <td>株式会社山下農林</td>\n      <td>富里支店</td>\n      <td>埼玉県西多摩郡檜原村松石7丁目3番5号 鳥越シャルム319</td>\n      <td>清水 美加子</td>\n      <td>xota@goto.jp</td>\n    </tr>\n    <tr>\n      <th>557</th>\n      <td>179.0</td>\n      <td>5.0</td>\n      <td>3640000.0</td>\n      <td>清水電気合同会社</td>\n      <td>清瀬支店</td>\n      <td>宮崎県横浜市戸塚区虎ノ門虎ノ門ヒルズ森タワー31丁目24番11号 南郷屋シティ907</td>\n      <td>斉藤 里佳</td>\n      <td>nakagawaminoru@yamada.com</td>\n    </tr>\n    <tr>\n      <th>46</th>\n      <td>106.0</td>\n      <td>5.0</td>\n      <td>3615000.0</td>\n      <td>合同会社山田ガス</td>\n      <td>横浜市都筑支店</td>\n      <td>岡山県鴨川市大中23丁目18番20号</td>\n      <td>西村 美加子</td>\n      <td>sotaro10@fujii.jp</td>\n    </tr>\n    <tr>\n      <th>145</th>\n      <td>120.0</td>\n      <td>6.0</td>\n      <td>3610000.0</td>\ ...

# %% [markdown]
# # 結果をメールに送信する

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# %%
email = "qcellsjp@gmail.com"
password = "trpiqwfvzgescosa"
send_to_email =["sungh.kim@qcells.com",]
subject = f'[実行完了] {filename}'

msg = MIMEMultipart('alternative')
msg['From'] = email
msg['To'] = ', '.join(send_to_email)
msg['Subject'] = subject

msg.attach(MIMEText(df4.to_html(), 'html'))

server = smtplib.SMTP("smtp.gmail.com",587)
server.starttls()
server.login(email, password)
text = msg.as_string()
server.sendmail(email, send_to_email, text)
server.quit()
# Out:
# (221,
#  b'2.0.0 closing connection e19-20020a056102355300b003a6f7c7a6a7sm3641142vss.27 - gsmtp')
